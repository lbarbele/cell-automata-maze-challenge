# %%
import math

import sys
sys.path.append('..')
from src.maze import Maze

# %%
initial_green_cells = [
  (1, 4),
  (2, 2), (2, 4), (2, 5),
  (3, 1), (3, 2), (3, 5), (3, 6),
  (4, 2), (4, 4), (4, 5),
  (5, 4),
]

# %%
maze = Maze(shape = (7, 8), greens = initial_green_cells)

for position in maze.solve():
  maze.draw(position)
  maze.evolve()

# %%
# maze.solve_random(tries = 10000)

# %%
# max_steps = 100
# max_dist = 0
# max_pos = (0, 0)
# max_pos_step = 0

# mazes = [maze]

# while len(mazes) < max_steps:
#   mz = mazes[-1].clone()
#   mz.evolve()
#   mazes.append(mz)

# positions = [set([(0, 0)])]

# for i in range(1, max_steps):
#   prv_mz = mazes[i - 1]
#   cur_mz = mazes[i]

#   prv_positions = positions[i - 1]
#   cur_positions = set()

#   for prv_pos in prv_positions:
#     for pos in prv_mz.get_valid_moves(prv_pos):
#       cur_positions.add(pos)
#       d = math.hypot(*pos)
#       if d > max_dist:
#         max_dist = d
#         max_pos = pos
#         max_pos_step = i

#   if len(cur_positions) == 0:
#     print('stopping at', i)
#     break

#   positions.append(cur_positions)

# # positions[-1]
# max_pos, max_pos_step
