# %%
import math

import sys
sys.path.append('..')
from src.maze import Maze

# %%
initial_green_cells = [
  (1, 4),
  (2, 2), (2, 4), (2, 5),
  (3, 1), (3, 2), (3, 5), (3, 6),
  (4, 2), (4, 4), (4, 5),
  (5, 4),
]

# %%
maze = Maze(shape = (7, 8), greens = initial_green_cells)

for position in maze.solve():
  maze.draw(position)
  maze.evolve()
